# %%
import numpy as np
import pandas as pd
import seaborn as sns
import scipy.stats as stats
import statsmodels.api as sm 
from scipy.linalg import eigh
from itertools import chain, combinations

# %%
# create correlated data
np.random.seed(0)
nobs = 100
nvar = 5
index = ['v1','v2','v3','v4','v5']
A = np.random.normal(loc=0,scale=0.1,size=nobs**2).reshape(nobs,nobs) 
cov = np.dot(A, A.transpose())
mean = np.random.normal(0,1,nobs)
data = np.random.multivariate_normal(mean=mean, cov=cov, size=nvar)
df = pd.DataFrame(data,index=index).transpose()

# %%
def regression (inp, outp): 
    model = sm.OLS(outp, inp)
    result = model.fit()
    print(result.summary())

# %%
def powerset(iterable): # see itertools from: docs.python.org/3/library/itertools.html
    s = list(iterable)
    list_ = chain.from_iterable(combinations(s, r) for r in range(2,len(s))) # exlude single element sets 
    return list_

# %%
def conv_to_list (tuples):
    list_ = [tuples[i] for i in range(len(tuples))]
    return list_

# %%
# test auf lineare unabhängigkeit!

# %%
for i in range(len(list(powerset(df)))):
    tuples = conv_to_list(list(powerset(df))[i])
    out_ = tuples[len(tuples)-1]
    in_ = tuples[0:len(tuples)-1]
    regression(df[in_],df[out_])
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                     v2   R-squared (uncentered):                   0.334
# Model:                            OLS   Adj. R-squared (uncentered):              0.327
# Method:                 Least Squares   F-statistic:                              49.66
# Date:                Tue, 23 Feb 2021   Prob (F-statistic):                    2.47e-10
# Time:                        10:29:31   Log-Likelihood:                         -148.23
# No. Observations:                 100   AIC:                                      298.5
# Df Residuals:                      99   BIC:                                      301.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# v1             0.5596      0.079      7.047      0.000       0.402       0.717
# ==============================================================================
# Omnibus:                        7.565   Durbin-Watson:                   2.101
# Prob(Omnibus):                  0.023   Jarque-Bera (JB):                7.579
# Skew:                           0.673   Prob(JB):                       0.0226
# Kurtosis:                       3.076   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                     v3   R-squared (uncentered):                   0.118
# Model:                            OLS   Adj. R-squared (uncentered):              0.109
# Method:                 Least Squares   F-statistic:                              13.23
# Date:                Tue, 23 Feb 2021   Prob (F-statistic):                    0.000440
# Time:                        10:29:31   Log-Likelihood:                         -164.31
# No. Observations:                 100   AIC:                                      330.6
# Df Residuals:                      99   BIC:                                      333.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# v1             0.3392      0.093      3.637      0.000       0.154       0.524
# ==============================================================================
# Omnibus:                        2.812   Durbin-Watson:                   2.023
# Prob(Omnibus):                  0.245   Jarque-Bera (JB):                2.525
# Skew:                           0.135   Prob(JB):                        0.283
# Kurtosis:                       3.730   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                     v4   R-squared (uncentered):                   0.290
# Model:                            OLS   Adj. R-squared (uncentered):              0.283
# Method:                 Least Squares   F-statistic:                              40.46
# Date:                Tue, 23 Feb 2021   Prob (F-statistic):                    6.23e-09
# Time:                        10:29:31   Log-Likelihood:                         -154.41
# No. Observations:                 100   AIC:                                      310.8
# Df Residuals:                      99   BIC:                                      313.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# v1             0.5374      0.084      6.361      0.000       0.370       0.705
# ==============================================================================
# Omnibus:                        1.678   Durbin-Watson:                   1.864
# Prob(Omnibus):                  0.432   Jarque-Bera (JB):                1.119
# Skew:                          -0.182   Prob(JB):                        0.572
# Kurtosis:                       3.368   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                     v5   R-squared (uncentered):                   0.238
# Model:                            OLS   Adj. R-squared (uncentered):              0.230
# Method:                 Least Squares   F-statistic:                              30.90
# Date:                Tue, 23 Feb 2021   Prob (F-statistic):                    2.31e-07
# Time:                        10:29:31   Log-Likelihood:                         -164.93
# No. Observations:                 100   AIC:                                      331.9
# Df Residuals:                      99   BIC:                                      334.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# v1             0.5217      0.094      5.559      0.000       0.335       0.708
# ==============================================================================
# Omnibus:                        3.677   Durbin-Watson:                   2.025
# Prob(Omnibus):                  0.159   Jarque-Bera (JB):                3.190
# Skew:                          -0.284   Prob(JB):                        0.203
# Kurtosis:                       3.665   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                     v3   R-squared (uncentered):                   0.145
# Model:                            OLS   Adj. R-squared (uncentered):              0.137
# Method:                 Least Squares   F-statistic:                              16.85
# Date:                Tue, 23 Feb 2021   Prob (F-statistic):                    8.33e-05
# Time:                        10:29:31   Log-Likelihood:                         -162.72
# No. Observations:                 100   AIC:                                      327.4
# Df Residuals:                      99   BIC:                                      330.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# v2             0.3892      0.095      4.105      0.000       0.201       0.577
# ==============================================================================
# Omnibus:                        0.339   Durbin-Watson:                   1.984
# Prob(Omnibus):                  0.844   Jarque-Bera (JB):                0.274
# Skew:                          -0.126   Prob(JB):                        0.872
# Kurtosis:                       2.949   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                     v4   R-squared (uncentered):                   0.290
# Model:                            OLS   Adj. R-squared (uncentered):              0.283
# Method:                 Least Squares   F-statistic:                              40.51
# Date:                Tue, 23 Feb 2021   Prob (F-statistic):                    6.14e-09
# Time:                        10:29:31   Log-Likelihood:                         -154.39
# No. Observations:                 100   AIC:                                      310.8
# Df Residuals:                      99   BIC:                                      313.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# v2             0.5552      0.087      6.365      0.000       0.382       0.728
# ==============================================================================
# Omnibus:                       11.381   Durbin-Watson:                   2.140
# Prob(Omnibus):                  0.003   Jarque-Bera (JB):               12.062
# Skew:                          -0.707   Prob(JB):                      0.00240
# Kurtosis:                       3.946   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                     v5   R-squared (uncentered):                   0.238
# Model:                            OLS   Adj. R-squared (uncentered):              0.230
# Method:                 Least Squares   F-statistic:                              30.95
# Date:                Tue, 23 Feb 2021   Prob (F-statistic):                    2.26e-07
# Time:                        10:29:31   Log-Likelihood:                         -164.91
# No. Observations:                 100   AIC:                                      331.8
# Df Residuals:                      99   BIC:                                      334.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# v2             0.5392      0.097      5.563      0.000       0.347       0.731
# ==============================================================================
# Omnibus:                        4.034   Durbin-Watson:                   2.145
# Prob(Omnibus):                  0.133   Jarque-Bera (JB):                4.533
# Skew:                          -0.142   Prob(JB):                        0.104
# Kurtosis:                       4.004   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                     v4   R-squared (uncentered):                   0.195
# Model:                            OLS   Adj. R-squared (uncentered):              0.187
# Method:                 Least Squares   F-statistic:                              24.00
# Date:                Tue, 23 Feb 2021   Prob (F-statistic):                    3.76e-06
# Time:                        10:29:31   Log-Likelihood:                         -160.69
# No. Observations:                 100   AIC:                                      323.4
# Df Residuals:                      99   BIC:                                      326.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# v3             0.4460      0.091      4.899      0.000       0.265       0.627
# ==============================================================================
# Omnibus:                        4.181   Durbin-Watson:                   2.218
# Prob(Omnibus):                  0.124   Jarque-Bera (JB):                4.247
# Skew:                          -0.232   Prob(JB):                        0.120
# Kurtosis:                       3.897   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                     v5   R-squared (uncentered):                   0.246
# Model:                            OLS   Adj. R-squared (uncentered):              0.238
# Method:                 Least Squares   F-statistic:                              32.23
# Date:                Tue, 23 Feb 2021   Prob (F-statistic):                    1.37e-07
# Time:                        10:29:31   Log-Likelihood:                         -164.42
# No. Observations:                 100   AIC:                                      330.8
# Df Residuals:                      99   BIC:                                      333.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# v3             0.5365      0.095      5.677      0.000       0.349       0.724
# ==============================================================================
# Omnibus:                        2.371   Durbin-Watson:                   2.338
# Prob(Omnibus):                  0.306   Jarque-Bera (JB):                1.982
# Skew:                          -0.104   Prob(JB):                        0.371
# Kurtosis:                       3.657   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                     v5   R-squared (uncentered):                   0.334
# Model:                            OLS   Adj. R-squared (uncentered):              0.328
# Method:                 Least Squares   F-statistic:                              49.70
# Date:                Tue, 23 Feb 2021   Prob (F-statistic):                    2.44e-10
# Time:                        10:29:31   Log-Likelihood:                         -158.18
# No. Observations:                 100   AIC:                                      318.4
# Df Residuals:                      99   BIC:                                      321.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# v4             0.6199      0.088      7.050      0.000       0.445       0.794
# ==============================================================================
# Omnibus:                        8.172   Durbin-Watson:                   2.132
# Prob(Omnibus):                  0.017   Jarque-Bera (JB):               11.778
# Skew:                          -0.345   Prob(JB):                      0.00277
# Kurtosis:                       4.533   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                     v3   R-squared (uncentered):                   0.168
# Model:                            OLS   Adj. R-squared (uncentered):              0.151
# Method:                 Least Squares   F-statistic:                              9.903
# Date:                Tue, 23 Feb 2021   Prob (F-statistic):                    0.000121
# Time:                        10:29:31   Log-Likelihood:                         -161.38
# No. Observations:                 100   AIC:                                      326.8
# Df Residuals:                      98   BIC:                                      332.0
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# v1             0.1824      0.112      1.635      0.105      -0.039       0.404
# v2             0.2803      0.115      2.433      0.017       0.052       0.509
# ==============================================================================
# Omnibus:                        1.111   Durbin-Watson:                   1.973
# Prob(Omnibus):                  0.574   Jarque-Bera (JB):                0.612
# Skew:                          -0.078   Prob(JB):                        0.736
# Kurtosis:                       3.350   Cond. No.                         1.94
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                     v4   R-squared (uncentered):                   0.368
# Model:                            OLS   Adj. R-squared (uncentered):              0.355
# Method:                 Least Squares   F-statistic:                              28.52
# Date:                Tue, 23 Feb 2021   Prob (F-statistic):                    1.74e-10
# Time:                        10:29:31   Log-Likelihood:                         -148.61
# No. Observations:                 100   AIC:                                      301.2
# Df Residuals:                      98   BIC:                                      306.4
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# v1             0.3404      0.098      3.467      0.001       0.146       0.535
# v2             0.3520      0.101      3.472      0.001       0.151       0.553
# ==============================================================================
# Omnibus:                        5.128   Durbin-Watson:                   1.958
# Prob(Omnibus):                  0.077   Jarque-Bera (JB):                4.549
# Skew:                          -0.503   Prob(JB):                        0.103
# Kurtosis:                       3.281   Cond. No.                         1.94
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                     v5   R-squared (uncentered):                   0.302
# Model:                            OLS   Adj. R-squared (uncentered):              0.287
# Method:                 Least Squares   F-statistic:                              21.17
# Date:                Tue, 23 Feb 2021   Prob (F-statistic):                    2.28e-08
# Time:                        10:29:31   Log-Likelihood:                         -160.56
# No. Observations:                 100   AIC:                                      325.1
# Df Residuals:                      98   BIC:                                      330.3
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# v1             0.3303      0.111      2.985      0.004       0.111       0.550
# v2             0.3420      0.114      2.993      0.003       0.115       0.569
# ==============================================================================
# Omnibus:                        3.670   Durbin-Watson:                   2.004
# Prob(Omnibus):                  0.160   Jarque-Bera (JB):                3.323
# Skew:                          -0.252   Prob(JB):                        0.190
# Kurtosis:                       3.737   Cond. No.                         1.94
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                     v4   R-squared (uncentered):                   0.365
# Model:                            OLS   Adj. R-squared (uncentered):              0.352
# Method:                 Least Squares   F-statistic:                              28.15
# Date:                Tue, 23 Feb 2021   Prob (F-statistic):                    2.18e-10
# Time:                        10:29:31   Log-Likelihood:                         -148.84
# No. Observations:                 100   AIC:                                      301.7
# Df Residuals:                      98   BIC:                                      306.9
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# v1             0.4377      0.086      5.118      0.000       0.268       0.607
# v3             0.2939      0.087      3.396      0.001       0.122       0.466
# ==============================================================================
# Omnibus:                        1.057   Durbin-Watson:                   2.040
# Prob(Omnibus):                  0.590   Jarque-Bera (JB):                0.564
# Skew:                          -0.053   Prob(JB):                        0.754
# Kurtosis:                       3.353   Cond. No.                         1.43
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                     v5   R-squared (uncentered):                   0.360
# Model:                            OLS   Adj. R-squared (uncentered):              0.347
# Method:                 Least Squares   F-statistic:                              27.55
# Date:                Tue, 23 Feb 2021   Prob (F-statistic):                    3.20e-10
# Time:                        10:29:31   Log-Likelihood:                         -156.21
# No. Observations:                 100   AIC:                                      316.4
# Df Residuals:                      98   BIC:                                      321.6
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# v1             0.3851      0.092      4.184      0.000       0.202       0.568
# v3             0.4027      0.093      4.323      0.000       0.218       0.588
# ==============================================================================
# Omnibus:                        3.052   Durbin-Watson:                   2.150
# Prob(Omnibus):                  0.217   Jarque-Bera (JB):                2.676
# Skew:                          -0.196   Prob(JB):                        0.262
# Kurtosis:                       3.699   Cond. No.                         1.43
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                     v5   R-squared (uncentered):                   0.378
# Model:                            OLS   Adj. R-squared (uncentered):              0.365
# Method:                 Least Squares   F-statistic:                              29.78
# Date:                Tue, 23 Feb 2021   Prob (F-statistic):                    7.85e-11
# Time:                        10:29:31   Log-Likelihood:                         -154.77
# No. Observations:                 100   AIC:                                      313.5
# Df Residuals:                      98   BIC:                                      318.8
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# v1             0.2657      0.101      2.627      0.010       0.065       0.466
# v4             0.4764      0.101      4.699      0.000       0.275       0.678
# ==============================================================================
# Omnibus:                        8.169   Durbin-Watson:                   2.054
# Prob(Omnibus):                  0.017   Jarque-Bera (JB):               11.951
# Skew:                          -0.337   Prob(JB):                      0.00254
# Kurtosis:                       4.554   Cond. No.                         1.83
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                     v4   R-squared (uncentered):                   0.356
# Model:                            OLS   Adj. R-squared (uncentered):              0.343
# Method:                 Least Squares   F-statistic:                              27.05
# Date:                Tue, 23 Feb 2021   Prob (F-statistic):                    4.43e-10
# Time:                        10:29:31   Log-Likelihood:                         -149.57
# No. Observations:                 100   AIC:                                      303.1
# Df Residuals:                      98   BIC:                                      308.3
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# v2             0.4466      0.090      4.941      0.000       0.267       0.626
# v3             0.2791      0.089      3.152      0.002       0.103       0.455
# ==============================================================================
# Omnibus:                        8.169   Durbin-Watson:                   2.292
# Prob(Omnibus):                  0.017   Jarque-Bera (JB):                7.906
# Skew:                          -0.582   Prob(JB):                       0.0192
# Kurtosis:                       3.736   Cond. No.                         1.50
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                     v5   R-squared (uncentered):                   0.350
# Model:                            OLS   Adj. R-squared (uncentered):              0.337
# Method:                 Least Squares   F-statistic:                              26.41
# Date:                Tue, 23 Feb 2021   Prob (F-statistic):                    6.68e-10
# Time:                        10:29:31   Log-Likelihood:                         -156.96
# No. Observations:                 100   AIC:                                      317.9
# Df Residuals:                      98   BIC:                                      323.1
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# v2             0.3866      0.097      3.973      0.000       0.193       0.580
# v3             0.3920      0.095      4.111      0.000       0.203       0.581
# ==============================================================================
# Omnibus:                        3.280   Durbin-Watson:                   2.269
# Prob(Omnibus):                  0.194   Jarque-Bera (JB):                3.112
# Skew:                          -0.169   Prob(JB):                        0.211
# Kurtosis:                       3.796   Cond. No.                         1.50
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                     v5   R-squared (uncentered):                   0.378
# Model:                            OLS   Adj. R-squared (uncentered):              0.365
# Method:                 Least Squares   F-statistic:                              29.80
# Date:                Tue, 23 Feb 2021   Prob (F-statistic):                    7.78e-11
# Time:                        10:29:31   Log-Likelihood:                         -154.76
# No. Observations:                 100   AIC:                                      313.5
# Df Residuals:                      98   BIC:                                      318.7
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# v2             0.2748      0.104      2.630      0.010       0.067       0.482
# v4             0.4762      0.101      4.696      0.000       0.275       0.677
# ==============================================================================
# Omnibus:                        7.599   Durbin-Watson:                   2.065
# Prob(Omnibus):                  0.022   Jarque-Bera (JB):               10.417
# Skew:                          -0.334   Prob(JB):                      0.00547
# Kurtosis:                       4.433   Cond. No.                         1.83
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                     v5   R-squared (uncentered):                   0.406
# Model:                            OLS   Adj. R-squared (uncentered):              0.394
# Method:                 Least Squares   F-statistic:                              33.48
# Date:                Tue, 23 Feb 2021   Prob (F-statistic):                    8.29e-12
# Time:                        10:29:31   Log-Likelihood:                         -152.48
# No. Observations:                 100   AIC:                                      309.0
# Df Residuals:                      98   BIC:                                      314.2
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# v3             0.3231      0.094      3.439      0.001       0.137       0.510
# v4             0.4785      0.093      5.143      0.000       0.294       0.663
# ==============================================================================
# Omnibus:                        7.876   Durbin-Watson:                   2.145
# Prob(Omnibus):                  0.019   Jarque-Bera (JB):               11.582
# Skew:                          -0.315   Prob(JB):                      0.00305
# Kurtosis:                       4.544   Cond. No.                         1.61
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                     v4   R-squared (uncentered):                   0.413
# Model:                            OLS   Adj. R-squared (uncentered):              0.395
# Method:                 Least Squares   F-statistic:                              22.77
# Date:                Tue, 23 Feb 2021   Prob (F-statistic):                    3.04e-11
# Time:                        10:29:31   Log-Likelihood:                         -144.88
# No. Observations:                 100   AIC:                                      295.8
# Df Residuals:                      97   BIC:                                      303.6
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# v1             0.2974      0.096      3.086      0.003       0.106       0.489
# v2             0.2859      0.101      2.828      0.006       0.085       0.487
# v3             0.2358      0.086      2.739      0.007       0.065       0.407
# ==============================================================================
# Omnibus:                        3.280   Durbin-Watson:                   2.116
# Prob(Omnibus):                  0.194   Jarque-Bera (JB):                2.677
# Skew:                          -0.378   Prob(JB):                        0.262
# Kurtosis:                       3.266   Cond. No.                         2.12
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                     v5   R-squared (uncentered):                   0.390
# Model:                            OLS   Adj. R-squared (uncentered):              0.371
# Method:                 Least Squares   F-statistic:                              20.70
# Date:                Tue, 23 Feb 2021   Prob (F-statistic):                    1.90e-10
# Time:                        10:29:31   Log-Likelihood:                         -153.78
# No. Observations:                 100   AIC:                                      313.6
# Df Residuals:                      97   BIC:                                      321.4
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# v1             0.2659      0.105      2.524      0.013       0.057       0.475
# v2             0.2429      0.111      2.198      0.030       0.024       0.462
# v3             0.3533      0.094      3.755      0.000       0.167       0.540
# ==============================================================================
# Omnibus:                        3.366   Durbin-Watson:                   2.141
# Prob(Omnibus):                  0.186   Jarque-Bera (JB):                3.060
# Skew:                          -0.212   Prob(JB):                        0.217
# Kurtosis:                       3.745   Cond. No.                         2.12
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                     v5   R-squared (uncentered):                   0.397
# Model:                            OLS   Adj. R-squared (uncentered):              0.378
# Method:                 Least Squares   F-statistic:                              21.25
# Date:                Tue, 23 Feb 2021   Prob (F-statistic):                    1.16e-10
# Time:                        10:29:31   Log-Likelihood:                         -153.25
# No. Observations:                 100   AIC:                                      312.5
# Df Residuals:                      97   BIC:                                      320.3
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# v1             0.1889      0.110      1.724      0.088      -0.029       0.406
# v2             0.1957      0.113      1.730      0.087      -0.029       0.420
# v4             0.4156      0.106      3.907      0.000       0.204       0.627
# ==============================================================================
# Omnibus:                        7.485   Durbin-Watson:                   2.018
# Prob(Omnibus):                  0.024   Jarque-Bera (JB):               10.094
# Skew:                          -0.335   Prob(JB):                      0.00643
# Kurtosis:                       4.405   Cond. No.                         2.25
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                     v5   R-squared (uncentered):                   0.436
# Model:                            OLS   Adj. R-squared (uncentered):              0.419
# Method:                 Least Squares   F-statistic:                              25.00
# Date:                Tue, 23 Feb 2021   Prob (F-statistic):                    4.56e-12
# Time:                        10:29:31   Log-Likelihood:                         -149.88
# No. Observations:                 100   AIC:                                      305.8
# Df Residuals:                      97   BIC:                                      313.6
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# v1             0.2226      0.098      2.277      0.025       0.029       0.417
# v3             0.2936      0.093      3.160      0.002       0.109       0.478
# v4             0.3712      0.103      3.619      0.000       0.168       0.575
# ==============================================================================
# Omnibus:                        7.654   Durbin-Watson:                   2.090
# Prob(Omnibus):                  0.022   Jarque-Bera (JB):               11.280
# Skew:                          -0.299   Prob(JB):                      0.00355
# Kurtosis:                       4.533   Cond. No.                         2.06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                     v5   R-squared (uncentered):                   0.432
# Model:                            OLS   Adj. R-squared (uncentered):              0.414
# Method:                 Least Squares   F-statistic:                              24.60
# Date:                Tue, 23 Feb 2021   Prob (F-statistic):                    6.39e-12
# Time:                        10:29:31   Log-Likelihood:                         -150.23
# No. Observations:                 100   AIC:                                      306.5
# Df Residuals:                      97   BIC:                                      314.3
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# v2             0.2160      0.102      2.113      0.037       0.013       0.419
# v3             0.2854      0.094      3.035      0.003       0.099       0.472
# v4             0.3821      0.102      3.738      0.000       0.179       0.585
# ==============================================================================
# Omnibus:                        7.613   Durbin-Watson:                   2.119
# Prob(Omnibus):                  0.022   Jarque-Bera (JB):               10.748
# Skew:                          -0.320   Prob(JB):                      0.00464
# Kurtosis:                       4.473   Cond. No.                         2.05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
