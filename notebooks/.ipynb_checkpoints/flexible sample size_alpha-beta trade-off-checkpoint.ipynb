# %%
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as stats
import numpy as np

# %%
# null hypothesis: N(0,1)
mu = 0
sigma = 1
alpha = 0.05

# sample data
mean = 3
sd = 1
num=1000

# beta = 0.2
critical_value = stats.norm.ppf(0.975) # alpha = 5%, two-tailed
rejection_area = np.linspace(critical_value, mu+5*sigma, num=num)
beta_area = np.linspace(mu-1*sigma, critical_value, num=num)


# plot null distribution
x = np.linspace(mu-1*sigma, mu+5*sigma, num=num)
curve = stats.norm.pdf(x=x, loc=mu, scale=sigma)
ax = sns.lineplot(x=x, y=curve, color='red')
# plot sample distribution 
sample_curve = stats.norm.pdf(x=x, loc=mean, scale=sd)
sns.lineplot(x=x, y=sample_curve, color='blue')
#shade in error areas 
ax.fill_between(x=beta_area, y1=stats.norm.pdf(x=beta_area, loc=mean, scale=sd), color='lightblue')
ax.fill_between(x=rejection_area, y1=stats.norm.pdf(x=rejection_area, loc=mu, scale=sigma), color='lightcoral')
plt.axvline(x=critical_value, color='black')
plt.text(s='critical \nvalue', x=1.2, y=0.3)
# plot expected value under H0
plt.axvline(x=mu, color='red')
plt.text(s='H0:\nmean=0', x=0.1, y=0.15, color='red')
plt.axvline(x=mean, color='blue')
plt.text(s='H1:\nmean=3', x=3.1, y=0.15 ,color='blue')
ax.set(xlabel='test statistic', ylabel='density')
plt.title('alpha=5%')
# Out:
# Text(0.5, 1.0, 'alpha=5%')

# %%
power = stats.norm.sf(x=critical_value, loc=mean, scale=sd)
beta = stats.norm.cdf(x=critical_value, loc=mean, scale=sd)
print(power)
print(beta)
power + beta
# Out:
# 0.8508384157958045
# 0.14916158420419545
# 1.0

# %%
# increase alpha area to show trade-off
new_alpha = 0.2
new_crit = stats.norm.isf(new_alpha/2)
print(critical_value)
print(new_crit)

new_alpha_area = np.linspace(new_crit, mu+5*sigma, num=num)
new_beta_area = np.linspace(mu-1*sigma, new_crit, num=num)
# Out:
# 1.959963984540054
# 1.2815515655446004

# %%
ax = sns.lineplot(x=x, y=curve, color='red')
sns.lineplot(x=x, y=sample_curve, color='blue')
ax.fill_between(x=new_beta_area, y1=stats.norm.pdf(x=new_beta_area, loc=mean, scale=sd), color='lightblue')
ax.fill_between(x=new_alpha_area, y1=stats.norm.pdf(x=new_alpha_area, loc=mu, scale=sigma), color='lightcoral')
plt.axvline(x=new_crit, color='black')
plt.text(s='critical \nvalue', x=1.3, y=0.3)
plt.axvline(x=mu, color='red')
plt.text(s='H0:\nmean=0', x=0.1, y=0.15, color='red')
plt.axvline(x=mean, color='blue')
plt.text(s='H1:\nmean=3', x=3.1, y=0.15 ,color='blue')
ax.set(xlabel='test statistic', ylabel='density')
plt.title('alpha=20%')
# Out:
# Text(0.5, 1.0, 'alpha=20%')

# %%
new_power = stats.norm.sf(x=new_crit, loc=mean, scale=sd)
new_beta = stats.norm.cdf(x=new_crit, loc=mean, scale=sd)
print(new_power)
print(new_beta)
new_power + new_beta
# Out:
# 0.9571425738271104
# 0.042857426172889575
# 1.0
