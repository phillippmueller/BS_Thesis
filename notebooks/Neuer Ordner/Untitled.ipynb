# %%
import pandas as pd

df = pd.read_csv(r'C:\Users\phili\OneDrive\Dokumente_One Drive\KIT\Bachelorarbeit\data\t_results.csv')

# %%
df
# Out:
#        Unnamed: 0    df=1   df=2   df=3   df=4   df=5   df=6   df=7   df=8  \
# 0    p1_statistic   6.314  2.920  2.354  2.132  2.016  1.944  1.895  1.860
# 1    p2_statistic  12.707  4.303  3.183  2.777  2.571  2.447  2.365  2.307
# 2  statistic_diff   6.393  1.383  0.829  0.645  0.555  0.503  0.470  0.447
#
#     df=9  ...  df=21  df=22  df=23  df=24  df=25  df=26  df=27  df=28  df=29  \
# 0  1.834  ...  1.721  1.718  1.714  1.711  1.709  1.706  1.704  1.702  1.700
# 1  2.263  ...  2.080  2.074  2.069  2.064  2.060  2.056  2.052  2.049  2.046
# 2  0.429  ...  0.359  0.356  0.355  0.353  0.351  0.350  0.348  0.347  0.346
#
#    df=30
# 0  1.698
# 1  2.043
# 2  0.345
#
# [3 rows x 31 columns]

# %%
df2 = df.transpose()

# %%
df2
# Out:
#                        0             1               2
# Unnamed: 0  p1_statistic  p2_statistic  statistic_diff
# df=1               6.314        12.707           6.393
# df=2                2.92         4.303           1.383
# df=3               2.354         3.183           0.829
# df=4               2.132         2.777           0.645
# df=5               2.016         2.571           0.555
# df=6               1.944         2.447           0.503
# df=7               1.895         2.365            0.47
# df=8                1.86         2.307           0.447
# df=9               1.834         2.263           0.429
# df=10              1.813         2.229           0.416
# df=11              1.796         2.201           0.405
# df=12              1.783         2.179           0.396
# df=13              1.771         2.161            0.39
# df=14              1.762         2.145           0.383
# df=15              1.754         2.132           0.378
# ...

# %%
df2.to_csv(r'C:\Users\phili\OneDrive\Dokumente_One Drive\KIT\Bachelorarbeit\data\t_transpose.csv')

# %%
cf = pd.read_csv(r'C:\Users\phili\OneDrive\Dokumente_One Drive\KIT\Bachelorarbeit\data\chi_results.csv')
cf2 = cf.transpose()
cf2.to_csv(r'C:\Users\phili\OneDrive\Dokumente_One Drive\KIT\Bachelorarbeit\data\chi_transpose.csv')

# %%
Ff = pd.read_csv(r'C:\Users\phili\OneDrive\Dokumente_One Drive\KIT\Bachelorarbeit\data\F_results.csv')
F2 = Ff.transpose()
Ff
# Out:
#     Unnamed: 0  t at p1=5%  t at p2=5%  t interval      p1  p2 at p1=5%  \
# 0          1,2        17.6        37.6        20.0  0.0498       0.0996
# 1          1,3         9.2        16.5         7.3  0.0496       0.0991
# 2          1,4         6.8        11.3         4.5  0.0492       0.0983
# 3          1,5         5.7         9.1         3.4  0.0489       0.0979
# 4          1,6         5.0         7.9         2.9  0.0498       0.0997
# ..         ...         ...         ...         ...     ...          ...
# 865      30,26         1.0         1.2         0.2  0.0382       0.0764
# 866      30,27         0.9         1.2         0.3  0.0478       0.0957
# 867      30,28         0.9         1.2         0.3  0.0457       0.0915
# 868      30,29         0.9         1.1         0.2  0.0438       0.0875
# 869      30,30         0.9         1.1         0.2  0.0419       0.0839
#
#      delta p at p1=5%      p2  p1 at p2=5%  delta p at p2=5%
# ...
